# %%
# %matplotlib inline
from geneticAlgorithm import GeneticAlgorithm
ga = GeneticAlgorithm()
ga.evolve_and_plot_weights()
# Out:
# Current generation: 1 , best fitness: 0.37
# Current generation: 2 , best fitness: 0.41
# Current generation: 3 , best fitness: 0.48
# Current generation: 4 , best fitness: 0.36
# Current generation: 5 , best fitness: 0.1
# Current generation: 6 , best fitness: 0.35
# Current generation: 7 , best fitness: 0.35
# Current generation: 8 , best fitness: 0.13
# Current generation: 9 , best fitness: 0.12
# Current generation: 10 , best fitness: 0.21
# Current generation: 11 , best fitness: 0.12
# Current generation: 12 , best fitness: 0.1
# Current generation: 13 , best fitness: 0.34
# Current generation: 14 , best fitness: -0.17
# Current generation: 15 , best fitness: -0.09
# Current generation: 16 , best fitness: -0.01
# Current generation: 17 , best fitness: 0.22
# Current generation: 18 , best fitness: -0.02
# Current generation: 19 , best fitness: -0.22
# Current generation: 20 , best fitness: 0.14
# Current generation: 21 , best fitness: -0.01
# ...
